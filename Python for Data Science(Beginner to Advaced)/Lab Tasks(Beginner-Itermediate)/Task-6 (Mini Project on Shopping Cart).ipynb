# %% [markdown]
# ## Task-6 - 21122063 - Drashty Ranpara

# %%
print('----------NOWAYHOME Furnitures - "Destination for a perfect home"--------------')
dictAcc={}

# Login checkup
def userPass():   
    checkAccount = input("Do you have an account (Y or N)?").strip()
    if (checkAccount == 'N' or checkAccount == 'n'):
        userName = input("Please Set Your New Username: ").strip()
        password = input("Please Set Your New Password: ").strip()
        if (userName in dictAcc):
            print("Username is taken")
            userPass()
        else:
            dictAcc[userName] = password 
            print("Congratulations! You have succesfully created an account!\n\nNow redirected to Login Page :")
            login(dictAcc)
    elif (checkAccount == 'Y' or checkAccount == 'y'):
        login(dictAcc)
        userPass() 
    else:
        print("\nOops Invalid answer, Try A gain!")
        userPass()

# Signup
def login(dictAcc):
    print(dictAcc)
    loginUserName,loginPass =input("Type in your Username: ").strip(),input("Type in your Password: ").strip()
    for key in dictAcc:
        if (loginUserName == key and loginPass == dictAcc[key]):
            print ("\nLogged in successfully as " + loginUserName)
            d={'a':{'Home decor':['Table Lamp','Cushions','Candles','Rugs','Vases']},
                'b':{'Furnitures-Indoor': ['Beds','Cabinets','Chairs','Shelves','Desks']},
                'c':{'Outdoor Furnitures': 
                     ['Shoe-case','Flower-stand','Instrumental-racks','Sitting Bench','Chair']},
                'd':{'Lights Interiors':
                     ['Floor-Lamps','Lanterns','LED-Bulbs','Delicate Light Hangings','Wall Lamp']}}
            for keys,values in d.items():
                print(keys)
                print(values)
            print('------------------------Choose any one key among a/b/c/d -------------------------')
            while(True):
                ans=input('Do you want to continue shopping (y/n) - ')
                if(ans=='y'):
                        if(input('item -') in d['a']['Home decor']):
                            homeinr=10000
                            bucket=homeinr
                        if(input('item -') in d['b']['Furnitures-Indoor']):
                            furnitureinr=20000
                            bucket=bucket+furnitureinr
                        if(input('item -') in d['c']['Outdoor Furnitures']):
                            ofurnitureinr=25000
                            bucket=bucket+ofurnitureinr
                        if(input('item -') in d['d']['Lights Interiors']):
                            lightsinr=7999
                            bucket=bucket+lightsinr
                break
            print("HAPPY SHOPPING!! :)\n Total Shopping INR = ",bucket)
            #print(d.items())
        else:
            for i in range(1,3):
                usernm,pwd=input('Username - ').strip(),input('Password - ').strip()
            print("\nNo more attempts left")
            userPass()
userPass()
# Out:
# ----------NOWAYHOME Furnitures - "Destination for a perfect home"--------------
# Do you have an account (Y or N)?y
# {}
# Type in your Username: sunny
# Type in your Password: s123
# Do you have an account (Y or N)?y
# {}
# Type in your Username: sunny
# Type in your Password: s123
# Do you have an account (Y or N)?n
# Please Set Your New Username: sunny
# Please Set Your New Password: s123
# Congratulations! You have succesfully created an account!
#
# Now redirected to Login Page :
# {'sunny': 's123'}
# Type in your Username: sunny
# Type in your Password: s123
#
# Logged in successfully as sunny
# a
# {'Home decor': ['Table Lamp', 'Cushions', 'Candles', 'Rugs', 'Vases']}
# b
# {'Furnitures-Indoor': ['Beds', 'Cabinets', 'Chairs', 'Shelves', 'Desks']}
# c
# {'Outdoor Furnitures': ['Shoe-case', 'Flower-stand', 'Instrumental-racks', 'Sitting Bench', 'Chair']}
# d
# {'Lights Interiors': ['Floor-Lamps', 'Lanterns', 'LED-Bulbs', 'Delicate Light Hangings', 'Wall Lamp']}
# ...
